# %% [markdown]
# <a href="https://colab.research.google.com/github/JCarnelosMV/Image_Analysis/blob/main/Porosity%20analysis_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/JCarnosMV/Image_Analysis.git
# Out:
# Cloning into 'Image_Analysis'...
# fatal: could not read Username for 'https://github.com': No such device or address
